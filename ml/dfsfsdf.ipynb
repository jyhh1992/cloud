# %%
import numpy as np
import pandas as pd

# %%
pip list
# Out:
# Package             Version
# ------------------- -------
# argon2-cffi         21.1.0
# attrs               21.2.0
# backcall            0.2.0
# bleach              4.1.0
# cffi                1.15.0
# cycler              0.11.0
# debugpy             1.5.1
# decorator           5.1.0
# defusedxml          0.7.1
# entrypoints         0.3
# importlib-resources 5.4.0
# ipykernel           6.5.0
# ipython             7.29.0
# ipython-genutils    0.2.0
# ipywidgets          7.6.5
# jedi                0.18.0
# Jinja2              3.0.2
# jsonschema          4.2.1
# jupyter             1.0.0
# jupyter-client      7.0.6
# jupyter-console     6.4.0
# jupyter-core        4.9.1
# jupyterlab-pygments 0.1.2
# jupyterlab-widgets  1.0.2
# kiwisolver          1.3.2
# MarkupSafe          2.0.1
# matplotlib          3.4.3
# matplotlib-inline   0.1.3
# mistune             0.8.4
# nbclient            0.5.5
# nbconvert           6.2.0
# nbformat            5.1.3
# nest-asyncio        1.5.1
# ...

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#      |████████████████████████████████| 39.3 MB 21.9 MB/s
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ubuntu/ml/mlVENV/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
data = "./carbon/my_carbon.csv.1"
df_carbon = pd.read_csv(data)

# %%
df_carbon.head()
# Out:
#   Unnamed: 0  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#   All values in billion tonnes of carbon per year (GtC/yr), for the globe. For values in billion tonnes of carbon dioxide per year (GtCO2/yr) , multiply the numbers below by 3.664.   \
# 0  Note: 1 billion tonnes C = 1 petagram of carbo...
# 1  All uncertainties represent ± 1 sigma error (6...
# 2  Emissions from fossil fuel combustion and indu...
# 3                                                NaN
# 4  Emissions from land-use change (uncertainty of...
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  Cite as: Friedlingstein et al. 2021 (see Summa...        NaN        NaN
# ...

# %%
df_carbon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 8 columns):
#  #   Column                                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                                               --------------  -----
#  0   Unnamed: 0                                                                                                                                                                           64 non-null     object
#  1   All values in billion tonnes of carbon per year (GtC/yr), for the globe. For values in billion tonnes of carbon dioxide per year (GtCO2/yr) , multiply the numbers below by 3.664.   72 non-null     object
# ...

# %%
df_carbon.describe()
# Out:
#        Unnamed: 0  \
# count          64
# unique         64
# top        GtC/yr
# freq            1
#
#        All values in billion tonnes of carbon per year (GtC/yr), for the globe. For values in billion tonnes of carbon dioxide per year (GtCO2/yr) , multiply the numbers below by 3.664.   \
# count                                                  72
# unique                                                 72
# top     Note: 1 billion tonnes C = 1 petagram of carbo...
# freq                                                    1
#
#                                                Unnamed: 2 Unnamed: 3  \
# count                                                  72         63
# unique                                                 68         57
# top     Cite as: Friedlingstein et al. 2021 (see Summa...    5.11884
# freq                                                    5          3
#
#         Unnamed: 4   Unnamed: 5               Unnamed: 6        Unnamed: 7
# ...

# %%
df_carbon.tail()
# Out:
#    Unnamed: 0  \
# 77       2016
# 78       2017
# 79       2018
# 80       2019
# 81       2020
#
#    All values in billion tonnes of carbon per year (GtC/yr), for the globe. For values in billion tonnes of carbon dioxide per year (GtCO2/yr) , multiply the numbers below by 3.664.   \
# 77                                        9.675889546
# 78                                        9.805059412
# 79                                        10.00167571
# 80                                        10.01705865
# 81                                        9.499797789
#
#       Unnamed: 2 Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 77   1.010800906    6.01092   2.93415469          2.8  0.199106369
# 78  0.9996941366     4.5666  2.839219869  3.524705882  0.203693613
# 79   1.052821699    5.11884  2.907691446  3.346470588  0.210855607
# 80    1.04405313    5.39496   2.97397468  2.692352941  0.215297542
# 81  0.8760897818    5.01264  2.994930931  2.924705882  0.218773919
#
# ...

# %%
data2 = "./carbon/my_carbon.csv.2"
df_carbon2 = pd.read_csv(data2)

# %%
df_carbon2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             273 non-null    object
#  1   Historical CO2 budget  284 non-null    object
#  2   Unnamed: 2             172 non-null    object
#  3   Unnamed: 3             272 non-null    object
#  4   Unnamed: 4             241 non-null    object
#  5   Unnamed: 5             272 non-null    object
#  6   Unnamed: 6             92 non-null     object
#  7   Unnamed: 7             172 non-null    object
# dtypes: object(8)
# memory usage: 18.0+ KB

# %%
df_carbon2.head(20)
# Out:
#    Unnamed: 0                              Historical CO2 budget  \
# 0         NaN  All values in billion tonnes of carbon per yea...
# 1         NaN  1 billion tonnes C = 1 petagram of carbon (10^...
# 2         NaN  Please note: The methods used to estimate the ...
# 3         NaN  Uncertainties: see the original papers for unc...
# 4         NaN  Cite as:  Friedlingstein et al (2021; see summ...
# 5         NaN  Fossil fuel combustion and cement production e...
# 6         NaN  Land-use change emissions:  As in Global Carbo...
# 7         NaN  Atmospheric CO2 growth rate: Joos, F. and Spah...
# 8         NaN  The ocean CO2 sink prior to 1959 is the averag...
# 9         NaN  The land sink is as in Global Carbon Budget fr...
# 10        NaN  Cement carbonation is the average of two estim...
# 11        NaN  The budget imbalance is the sum of emissions (...
# 12        NaN                                                NaN
# ...
