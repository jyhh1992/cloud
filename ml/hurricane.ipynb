# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = "./cc/my_carbon1.csv"
df_carbon = pd.read_csv(data)

# %%
df_carbon.head()
# Out:
#    Year  fossil emissions excluding carbonation  land-use change emissions  \
# 0  1959                                2.417082                   1.845519
# 1  1960                                2.561936                   1.853712
# 2  1961                                2.570268                   1.862120
# 3  1962                                2.661042                   1.790599
# 4  1963                                2.803364                   1.651862
#
#    atmospheric growth  ocean sink  land sink  cement carbonation sink  \
# 0             2.03904    0.918022   0.395882                 0.012684
# 1             1.50804    0.899129   1.156471                 0.013839
# 2             1.65672    0.754060   0.611176                 0.014726
# 3             1.18944    0.800369   1.155294                 0.015871
# 4             1.21068    0.981130   1.060588                 0.016863
#
#    budget imbalance
# 0          0.896973
# 1          0.838170
# 2          1.395706
# ...

# %%
df_sample1 = df_carbon.loc[21:,:]
df_sample1.head()
# Out:
#     Year  fossil emissions excluding carbonation  land-use change emissions  \
# 21  1980                                5.320036                   1.130973
# 22  1981                                5.192934                   1.177646
# 23  1982                                5.151681                   1.155482
# 24  1983                                5.185052                   1.272159
# 25  1984                                5.364824                   1.411811
#
#     atmospheric growth  ocean sink  land sink  cement carbonation sink  \
# 21             3.63204    1.666825   0.454118                 0.043861
# 22             2.46384    1.666857   2.241176                 0.044741
# 23             2.08152    1.815808   1.540000                 0.045586
# 24             3.92940    1.954881   0.291176                 0.047107
# 25             2.61252    1.840391   2.670000                 0.048557
#
#     budget imbalance
# 21          0.654166
# 22         -0.046034
# ...

# %%
df_carbon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Year                                    62 non-null     int64
#  1   fossil emissions excluding carbonation  62 non-null     float64
#  2   land-use change emissions               62 non-null     float64
#  3   atmospheric growth                      62 non-null     float64
#  4   ocean sink                              62 non-null     float64
#  5   land sink                               62 non-null     float64
#  6   cement carbonation sink                 62 non-null     float64
#  7   budget imbalance                        62 non-null     float64
# dtypes: float64(7), int64(1)
# memory usage: 4.0 KB

# %%
data3 = "./cc/my_carbon3.csv"
df_carbon3 = pd.read_csv(data3)

# %%
df_carbon3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Year                                    62 non-null     int64
#  1   fossil.emissions.excluding.carbonation  62 non-null     float64
#  2   Coal                                    62 non-null     float64
#  3   Oil                                     62 non-null     float64
#  4   Gas                                     62 non-null     float64
#  5   Cement.emission                         62 non-null     float64
#  6   Flaring                                 62 non-null     float64
#  7   Other                                   62 non-null     float64
#  8   Per.Capita                              62 non-null     float64
# dtypes: float64(8), int64(1)
# memory usage: 4.5 KB

# %%
df_carbon3.head()
# Out:
#    Year  fossil.emissions.excluding.carbonation         Coal          Oil  \
# 0  1959                             2417.082061  1350.331111   792.950715
# 1  1960                             2561.936046  1406.031937   853.419525
# 2  1961                             2570.268187  1348.886839   904.431014
# 3  1962                             2661.041666  1344.951862   972.212623
# 4  1963                             2803.363645  1394.443709  1039.158429
#
#           Gas  Cement.emission    Flaring     Other  Per.Capita
# 0  206.897210        39.615338  25.025527  2.262159    0.811217
# 1  227.713003        42.935500  24.328661  7.507421    0.844144
# 2  240.664432        44.780000  23.531405  7.974495    0.831306
# 3  264.042833        48.118239  23.452728  8.263382    0.844662
# 4  285.647352        50.746915  24.701470  8.665770    0.873050

# %%
df_sample3 = df_carbon3.loc[21:,:]
df_sample3.head()
# Out:
#     Year  fossil.emissions.excluding.carbonation         Coal          Oil  \
# 21  1980                             5320.036440  1925.425097  2445.458246
# 22  1981                             5192.934001  1920.786352  2332.905946
# 23  1982                             5151.681298  1954.243777  2276.170302
# 24  1983                             5185.052281  2007.565340  2250.393965
# 25  1984                             5364.824474  2102.722133  2273.937469
#
#            Gas  Cement.emission    Flaring      Other  Per.Capita
# 21  741.685019       107.954125  86.358281  13.155670    1.193367
# 22  753.929749       107.830112  64.743896  12.737946    1.144575
# 23  737.188865       107.461493  64.331565  12.285295    1.115714
# 24  745.837063       109.932383  58.149786  13.173743    1.103304
# 25  810.618423       112.241889  51.047959  14.256602    1.121407

# %%
datah = "./cc/hry.txt"
df_hry = pd.read_csv(datah,delimiter='\t')

# %%
df_hry.head()
# Out:
#    Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  2004            86            453.50          51           215.00
# 1  1997            95            569.25          58           233.25
# 2  1992           101            570.50          59           263.75
# 3  2015            95            498.75          54           226.75
# 4  2018            99            477.75          58           204.00
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy
# 0                  32                       96.0                      1018.2
# 1                  28                       94.5                      1166.3
# 2                  32                       91.5                      1198.4
# 3                  39                       90.0                      1058.5
# 4                  30                       84.0                       989.8

# %%
df_hry2 = df_hry.copy()

# %%
df_hry2.head()
# Out:
#    Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  2004            86            453.50          51           215.00
# 1  1997            95            569.25          58           233.25
# 2  1992           101            570.50          59           263.75
# 3  2015            95            498.75          54           226.75
# 4  2018            99            477.75          58           204.00
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy
# 0                  32                       96.0                      1018.2
# 1                  28                       94.5                      1166.3
# 2                  32                       91.5                      1198.4
# 3                  39                       90.0                      1058.5
# 4                  30                       84.0                       989.8

# %%
df_hry3 = np.sort(df_hry2,axis=0)

# %%
df_hry3
# Out:
# array([[1980.  ,   68.  ,  289.5 ,   38.  ,  107.75,   15.  ,   19.5 ,
#          527.1 ],
#        [1981.  ,   72.  ,  309.  ,   39.  ,  113.25,   16.  ,   27.75,
#          569.1 ],
#        [1982.  ,   74.  ,  314.25,   39.  ,  119.25,   18.  ,   31.  ,
#          571.  ],
#        [1983.  ,   74.  ,  332.  ,   39.  ,  119.5 ,   19.  ,   33.25,
#          577.1 ],
#        [1984.  ,   75.  ,  334.  ,   39.  ,  121.5 ,   19.  ,   33.75,
#          580.2 ],
#        [1985.  ,   77.  ,  337.5 ,   39.  ,  125.  ,   19.  ,   34.25,
#          581.7 ],
#        [1986.  ,   78.  ,  345.  ,   40.  ,  130.  ,   20.  ,   35.5 ,
#          598.3 ],
#        [1987.  ,   79.  ,  355.75,   41.  ,  133.  ,   20.  ,   36.5 ,
#          619.2 ],
#        [1988.  ,   79.  ,  356.75,   42.  ,  134.  ,   20.  ,   36.5 ,
#          624.4 ],
#        [1989.  ,   79.  ,  356.75,   42.  ,  135.75,   20.  ,   37.75,
#          627.5 ],
# ...

# %%
df_hry3.view()
# Out:
# array([[1980.  ,   68.  ,  289.5 ,   38.  ,  107.75,   15.  ,   19.5 ,
#          527.1 ],
#        [1981.  ,   72.  ,  309.  ,   39.  ,  113.25,   16.  ,   27.75,
#          569.1 ],
#        [1982.  ,   74.  ,  314.25,   39.  ,  119.25,   18.  ,   31.  ,
#          571.  ],
#        [1983.  ,   74.  ,  332.  ,   39.  ,  119.5 ,   19.  ,   33.25,
#          577.1 ],
#        [1984.  ,   75.  ,  334.  ,   39.  ,  121.5 ,   19.  ,   33.75,
#          580.2 ],
#        [1985.  ,   77.  ,  337.5 ,   39.  ,  125.  ,   19.  ,   34.25,
#          581.7 ],
#        [1986.  ,   78.  ,  345.  ,   40.  ,  130.  ,   20.  ,   35.5 ,
#          598.3 ],
#        [1987.  ,   79.  ,  355.75,   41.  ,  133.  ,   20.  ,   36.5 ,
#          619.2 ],
#        [1988.  ,   79.  ,  356.75,   42.  ,  134.  ,   20.  ,   36.5 ,
#          624.4 ],
#        [1989.  ,   79.  ,  356.75,   42.  ,  135.75,   20.  ,   37.75,
#          627.5 ],
# ...

# %%
df_hry4 = pd.DataFrame(df_hry3,columns=['Year',	'Named Storms',	'Named Storm Days',	'Hurricanes',	'Hurricanes Days',	'Cat. 3+ Hurricanes',	'Cat. 3+ Hurricanes Days ▴',	'Accumulated Cyclone Energy'])

# %%
df_hry4.to_csv('./cc/ssaa.csv')

# %%
dataf="./cc/ssaa.csv"
df_h = pd.read_csv(dataf)

# %%
df_h.head()
# Out:
#    Unnamed: 0    Year  Named Storms  Named Storm Days  Hurricanes  \
# 0           0  1980.0          68.0            289.50        38.0
# 1           1  1981.0          72.0            309.00        39.0
# 2           2  1982.0          74.0            314.25        39.0
# 3           3  1983.0          74.0            332.00        39.0
# 4           4  1984.0          75.0            334.00        39.0
#
#    Hurricanes Days  Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  \
# 0           107.75                15.0                      19.50
# 1           113.25                16.0                      27.75
# 2           119.25                18.0                      31.00
# 3           119.50                19.0                      33.25
# 4           121.50                19.0                      33.75
#
#    Accumulated Cyclone Energy
# 0                       527.1
# 1                       569.1
# 2                       571.0
# 3                       577.1
# ...

# %%
df_sample2 = df_h.loc[:,['Year',	'Named Storms',	'Named Storm Days',	'Hurricanes',	'Hurricanes Days',	'Cat. 3+ Hurricanes',	'Cat. 3+ Hurricanes Days ▴',	'Accumulated Cyclone Energy']]
df_sample2.head()
# Out:
#      Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  1980.0          68.0            289.50        38.0           107.75
# 1  1981.0          72.0            309.00        39.0           113.25
# 2  1982.0          74.0            314.25        39.0           119.25
# 3  1983.0          74.0            332.00        39.0           119.50
# 4  1984.0          75.0            334.00        39.0           121.50
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy
# 0                15.0                      19.50                       527.1
# 1                16.0                      27.75                       569.1
# 2                18.0                      31.00                       571.0
# 3                19.0                      33.25                       577.1
# 4                19.0                      33.75                       580.2

# %%
print(pd.merge(df_sample2,df_sample1))
# Out:
#       Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0   1980.0          68.0            289.50        38.0           107.75
# 1   1981.0          72.0            309.00        39.0           113.25
# 2   1982.0          74.0            314.25        39.0           119.25
# 3   1983.0          74.0            332.00        39.0           119.50
# 4   1984.0          75.0            334.00        39.0           121.50
# 5   1985.0          77.0            337.50        39.0           125.00
# 6   1986.0          78.0            345.00        40.0           130.00
# 7   1987.0          79.0            355.75        41.0           133.00
# 8   1988.0          79.0            356.75        42.0           134.00
# 9   1989.0          79.0            356.75        42.0           135.75
# 10  1990.0          79.0            358.00        43.0           138.50
# 11  1991.0          80.0            360.50        43.0           140.25
# ...

# %%
df_energy=pd.merge(df_sample2,df_sample3)

# %%
df_hop=pd.merge(df_sample2,df_sample1)

# %%
df_energy.head()
# Out:
#      Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  1980.0          68.0            289.50        38.0           107.75
# 1  1981.0          72.0            309.00        39.0           113.25
# 2  1982.0          74.0            314.25        39.0           119.25
# 3  1983.0          74.0            332.00        39.0           119.50
# 4  1984.0          75.0            334.00        39.0           121.50
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy  \
# 0                15.0                      19.50                       527.1
# 1                16.0                      27.75                       569.1
# 2                18.0                      31.00                       571.0
# 3                19.0                      33.25                       577.1
# 4                19.0                      33.75                       580.2
#
#    fossil.emissions.excluding.carbonation         Coal          Oil  \
# ...

# %%
df_energy.to_csv('./cc/energy2.csv')

# %%
df_energy.head()
# Out:
#      Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  1980.0          68.0            289.50        38.0           107.75
# 1  1981.0          72.0            309.00        39.0           113.25
# 2  1982.0          74.0            314.25        39.0           119.25
# 3  1983.0          74.0            332.00        39.0           119.50
# 4  1984.0          75.0            334.00        39.0           121.50
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy  \
# 0                15.0                      19.50                       527.1
# 1                16.0                      27.75                       569.1
# 2                18.0                      31.00                       571.0
# 3                19.0                      33.25                       577.1
# 4                19.0                      33.75                       580.2
#
#    fossil.emissions.excluding.carbonation         Coal          Oil  \
# ...

# %%
df_hop.head()
# Out:
#      Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  1980.0          68.0            289.50        38.0           107.75
# 1  1981.0          72.0            309.00        39.0           113.25
# 2  1982.0          74.0            314.25        39.0           119.25
# 3  1983.0          74.0            332.00        39.0           119.50
# 4  1984.0          75.0            334.00        39.0           121.50
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy  \
# 0                15.0                      19.50                       527.1
# 1                16.0                      27.75                       569.1
# 2                18.0                      31.00                       571.0
# 3                19.0                      33.25                       577.1
# 4                19.0                      33.75                       580.2
#
#    fossil emissions excluding carbonation  land-use change emissions  \
# ...

# %%
df_hop.to_csv('./cc/merge.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6803/556770664.py in <module>
# ----> 1 df_hop.to_csv('./cc/merge.csv')
#
# NameError: name 'df_hop' is not defined

# %%
df_hop.keys()
# Out:
# Index(['Year', 'Named Storms', 'Named Storm Days', 'Hurricanes',
#        'Hurricanes Days', 'Cat. 3+ Hurricanes', 'Cat. 3+ Hurricanes Days ▴',
#        'Accumulated Cyclone Energy', 'fossil emissions excluding carbonation',
#        'land-use change emissions', 'atmospheric growth', 'ocean sink',
#        'land sink', 'cement carbonation sink', 'budget imbalance'],
#       dtype='object')

# %%
pd.plotting.scatter_matrix(df_hop,figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Named Storms', ylabel='Year'>,
#         <AxesSubplot:xlabel='Named Storm Days', ylabel='Year'>,
#         <AxesSubplot:xlabel='Hurricanes', ylabel='Year'>,
#         <AxesSubplot:xlabel='Hurricanes Days', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cat. 3+ Hurricanes', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cat. 3+ Hurricanes Days ▴', ylabel='Year'>,
#         <AxesSubplot:xlabel='Accumulated Cyclone Energy', ylabel='Year'>,
#         <AxesSubplot:xlabel='fossil emissions excluding carbonation', ylabel='Year'>,
#         <AxesSubplot:xlabel='land-use change emissions', ylabel='Year'>,
#         <AxesSubplot:xlabel='atmospheric growth', ylabel='Year'>,
#         <AxesSubplot:xlabel='ocean sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='land sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='cement carbonation sink', ylabel='Year'>,
# ...

# %%
pd.plotting.scatter_matrix(df_energy,figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Named Storms', ylabel='Year'>,
#         <AxesSubplot:xlabel='Named Storm Days', ylabel='Year'>,
#         <AxesSubplot:xlabel='Hurricanes', ylabel='Year'>,
#         <AxesSubplot:xlabel='Hurricanes Days', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cat. 3+ Hurricanes', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cat. 3+ Hurricanes Days ▴', ylabel='Year'>,
#         <AxesSubplot:xlabel='Accumulated Cyclone Energy', ylabel='Year'>,
#         <AxesSubplot:xlabel='fossil.emissions.excluding.carbonation', ylabel='Year'>,
#         <AxesSubplot:xlabel='Coal', ylabel='Year'>,
#         <AxesSubplot:xlabel='Oil', ylabel='Year'>,
#         <AxesSubplot:xlabel='Gas', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cement.emission', ylabel='Year'>,
#         <AxesSubplot:xlabel='Flaring', ylabel='Year'>,
#         <AxesSubplot:xlabel='Other', ylabel='Year'>,
# ...

# %%
df_energy.describe()
# Out:
#               Year  Named Storms  Named Storm Days  Hurricanes  \
# count    41.000000     41.000000         41.000000   41.000000
# mean   2000.000000     85.926829        407.932927   47.170732
# std      11.979149      8.370753         65.051855    5.978722
# min    1980.000000     68.000000        289.500000   38.000000
# 25%    1990.000000     79.000000        358.000000   43.000000
# 50%    2000.000000     86.000000        404.000000   47.000000
# 75%    2010.000000     91.000000        447.750000   51.000000
# max    2020.000000    103.000000        570.500000   59.000000
#
#        Hurricanes Days  Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  \
# count        41.000000           41.000000                  41.000000
# mean        165.908537           23.804878                  52.908537
# std          36.175732            4.776084                  19.714823
# min         107.750000           15.000000                  19.500000
# ...

# %%
import seaborn as sns

# %%
ig = plt.figure(figsize=(20,20))
sns.heatmap(df_energy.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df_energy, x='Named Storms', y='fossil.emissions.excluding.carbonation')
plt.title('cal')
# seaborn으로 다음의 차트가 그려보세요.
plt.show()

# %%
df_energy.columns
# Out:
# Index(['Year', 'Named Storms', 'Named Storm Days', 'Hurricanes',
#        'Hurricanes Days', 'Cat. 3+ Hurricanes', 'Cat. 3+ Hurricanes Days ▴',
#        'Accumulated Cyclone Energy', 'fossil.emissions.excluding.carbonation',
#        'Coal', 'Oil', 'Gas', 'Cement.emission', 'Flaring', 'Other',
#        'Per.Capita'],
#       dtype='object')

# %%
pd.plotting.scatter_matrix(df_y,figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Year'>,
#         <AxesSubplot:xlabel='fossil emissions excluding carbonation', ylabel='Year'>,
#         <AxesSubplot:xlabel='land-use change emissions', ylabel='Year'>,
#         <AxesSubplot:xlabel='atmospheric growth', ylabel='Year'>,
#         <AxesSubplot:xlabel='ocean sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='land sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='cement carbonation sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='budget imbalance', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Fires'>,
#         <AxesSubplot:xlabel='fossil emissions excluding carbonation', ylabel='Fires'>,
#         <AxesSubplot:xlabel='land-use change emissions', ylabel='Fires'>,
#         <AxesSubplot:xlabel='atmospheric growth', ylabel='Fires'>,
# ...

# %%
pd.plotting.scatter_matrix(df_y2,figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Year'>,
#         <AxesSubplot:xlabel='fossil.emissions.excluding.carbonation', ylabel='Year'>,
#         <AxesSubplot:xlabel='Coal', ylabel='Year'>,
#         <AxesSubplot:xlabel='Oil', ylabel='Year'>,
#         <AxesSubplot:xlabel='Gas', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cement.emission', ylabel='Year'>,
#         <AxesSubplot:xlabel='Flaring', ylabel='Year'>,
#         <AxesSubplot:xlabel='Other', ylabel='Year'>,
#         <AxesSubplot:xlabel='Per.Capita', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Fires'>,
#         <AxesSubplot:xlabel='fossil.emissions.excluding.carbonation', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Coal', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Oil', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Gas', ylabel='Fires'>,
# ...
