# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = "./cc/merge.csv"
df_fossil = pd.read_csv(data)

# %%
data2 = "./cc/energy2.csv"
df_energy = pd.read_csv(data2)

# %%
df_fossil.head()
# Out:
#    Unnamed: 0    Year  Named Storms  Named Storm Days  Hurricanes  \
# 0           0  1980.0          68.0            289.50        38.0
# 1           1  1981.0          72.0            309.00        39.0
# 2           2  1982.0          74.0            314.25        39.0
# 3           3  1983.0          74.0            332.00        39.0
# 4           4  1984.0          75.0            334.00        39.0
#
#    Hurricanes Days  Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  \
# 0           107.75                15.0                      19.50
# 1           113.25                16.0                      27.75
# 2           119.25                18.0                      31.00
# 3           119.50                19.0                      33.25
# 4           121.50                19.0                      33.75
#
#    Accumulated Cyclone Energy  fossil emissions excluding carbonation  \
# 0                       527.1                                5.320036
# ...

# %%
df_energy.head()
# Out:
#    Unnamed: 0    Year  Named Storms  Named Storm Days  Hurricanes  \
# 0           0  1980.0          68.0            289.50        38.0
# 1           1  1981.0          72.0            309.00        39.0
# 2           2  1982.0          74.0            314.25        39.0
# 3           3  1983.0          74.0            332.00        39.0
# 4           4  1984.0          75.0            334.00        39.0
#
#    Hurricanes Days  Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  \
# 0           107.75                15.0                      19.50
# 1           113.25                16.0                      27.75
# 2           119.25                18.0                      31.00
# 3           119.50                19.0                      33.25
# 4           121.50                19.0                      33.75
#
#    Accumulated Cyclone Energy  fossil.emissions.excluding.carbonation  \
# 0                       527.1                             5320.036440
# ...

# %%
df_energy2 = df_energy.rename(columns={df_energy.columns[0]:'tt'})

# %%
df_energy = df_energy2.drop(['tt'],axis=1)

# %%
df_energy
# Out:
#       Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0   1980.0          68.0            289.50        38.0           107.75
# 1   1981.0          72.0            309.00        39.0           113.25
# 2   1982.0          74.0            314.25        39.0           119.25
# 3   1983.0          74.0            332.00        39.0           119.50
# 4   1984.0          75.0            334.00        39.0           121.50
# 5   1985.0          77.0            337.50        39.0           125.00
# 6   1986.0          78.0            345.00        40.0           130.00
# 7   1987.0          79.0            355.75        41.0           133.00
# 8   1988.0          79.0            356.75        42.0           134.00
# 9   1989.0          79.0            356.75        42.0           135.75
# 10  1990.0          79.0            358.00        43.0           138.50
# 11  1991.0          80.0            360.50        43.0           140.25
# ...

# %%
df_1 = df_fossil.rename(columns={df_fossil.columns[0]:'tt'})
df_fossil = df_1.drop(['tt'],axis=1)

# %%
df_fossil.head()
# Out:
#      Year  Named Storms  Named Storm Days  Hurricanes  Hurricanes Days  \
# 0  1980.0          68.0            289.50        38.0           107.75
# 1  1981.0          72.0            309.00        39.0           113.25
# 2  1982.0          74.0            314.25        39.0           119.25
# 3  1983.0          74.0            332.00        39.0           119.50
# 4  1984.0          75.0            334.00        39.0           121.50
#
#    Cat. 3+ Hurricanes  Cat. 3+ Hurricanes Days ▴  Accumulated Cyclone Energy  \
# 0                15.0                      19.50                       527.1
# 1                16.0                      27.75                       569.1
# 2                18.0                      31.00                       571.0
# 3                19.0                      33.25                       577.1
# 4                19.0                      33.75                       580.2
#
#    fossil emissions excluding carbonation  land-use change emissions  \
# ...

# %%
ig = plt.figure(figsize=(20,20))
sns.heatmap(df_fossil.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
ig = plt.figure(figsize=(20,20))
sns.heatmap(df_energy.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
plt.plot(X_test, y_test,'o')
plt.plot(X_test, y_pred)
plt.title('linear ')
plt.show()

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df_energy.d

# %%
X = df_energy[ 'Named Storms']
y = df_energy['Oil']

# %%
X = df_energy['Year', 'Named Storms', 'Named Storm Days', 'Hurricanes',
       'Hurricanes Days', 'Cat. 3+ Hurricanes', 'Cat. 3+ Hurricanes Days ▴','Accumulated Cyclone Energy']
y = df_energy['fossil.emissions.excluding.carbonation',
       'Coal', 'Oil', 'Gas', 'Cement.emission']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/ml/mlVENV/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/ml/mlVENV/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/ml/mlVENV/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Year', 'Named Storms', 'Named Storm Days', 'Hurricanes', 'Hurricanes Days', 'Cat. 3+ Hurricanes', 'Cat. 3+ Hurricanes Days ▴', 'Accumulated Cyclone Energy')
# ...

# %%
df_energy.columns
# Out:
# Index(['Year', 'Named Storms', 'Named Storm Days', 'Hurricanes',
#        'Hurricanes Days', 'Cat. 3+ Hurricanes', 'Cat. 3+ Hurricanes Days ▴',
#        'Accumulated Cyclone Energy', 'fossil.emissions.excluding.carbonation',
#        'Coal', 'Oil', 'Gas', 'Cement.emission', 'Flaring', 'Other',
#        'Per.Capita'],
#       dtype='object')
