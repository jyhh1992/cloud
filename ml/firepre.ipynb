# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = "./cc/wild.csv"
df_ff = pd.read_csv(data)

# %%
data1 = "./cc/my_carbon1.csv"
df_carbon1 = pd.read_csv(data1)

# %%
df_wilds = df_carbon1.loc[24:,:]
df_wilds.head()
# Out:
#     Year  fossil emissions excluding carbonation  land-use change emissions  \
# 24  1983                                5.185052                   1.272159
# 25  1984                                5.364824                   1.411811
# 26  1985                                5.545165                   1.337713
# 27  1986                                5.627627                   1.317747
# 28  1987                                5.804092                   1.263666
#
#     atmospheric growth  ocean sink  land sink  cement carbonation sink  \
# 24             3.92940    1.954881   0.291176                 0.047107
# 25             2.61252    1.840391   2.670000                 0.048557
# 26             3.48336    1.723412   2.547647                 0.049961
# 27             2.12400    1.754050   2.161176                 0.052336
# 28             5.64984    1.850043   0.381176                 0.054798
#
#     budget imbalance
# 24          0.234647
# 25         -0.394832
# ...

# %%
df_y =(pd.merge(df_ff,df_wilds))
df_y.to_csv('./cc/worldfire.csv')

# %%
df_y.head()
# Out:
#    Year  Fires    Acres  fossil emissions excluding carbonation  \
# 0  1983  18229  1323666                                5.185052
# 1  1984  20493  1148409                                5.364824
# 2  1985  82591  2896147                                5.545165
# 3  1986  85907  2719162                                5.627627
# 4  1987  71300  2447296                                5.804092
#
#    land-use change emissions  atmospheric growth  ocean sink  land sink  \
# 0                   1.272159             3.92940    1.954881   0.291176
# 1                   1.411811             2.61252    1.840391   2.670000
# 2                   1.337713             3.48336    1.723412   2.547647
# 3                   1.317747             2.12400    1.754050   2.161176
# 4                   1.263666             5.64984    1.850043   0.381176
#
#    cement carbonation sink  budget imbalance
# 0                 0.047107          0.234647
# 1                 0.048557         -0.394832
# ...

# %%
df_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Year                                    38 non-null     int64
#  1   Fires                                   38 non-null     int64
#  2   Acres                                   38 non-null     int64
#  3   fossil emissions excluding carbonation  38 non-null     float64
#  4   land-use change emissions               38 non-null     float64
#  5   atmospheric growth                      38 non-null     float64
#  6   ocean sink                              38 non-null     float64
#  7   land sink                               38 non-null     float64
#  8   cement carbonation sink                 38 non-null     float64
#  9   budget imbalance                        38 non-null     float64
# dtypes: float64(7), int64(3)
# ...

# %%
data3 = "./cc/my_carbon3.csv"
df_carbon3 = pd.read_csv(data3)

# %%
df_wilds2 = df_carbon3.loc[24:,:]
df_wilds2.head()
# Out:
#     Year  fossil.emissions.excluding.carbonation         Coal          Oil  \
# 24  1983                             5185.052281  2007.565340  2250.393965
# 25  1984                             5364.824474  2102.722133  2273.937469
# 26  1985                             5545.164717  2250.843592  2274.184209
# 27  1986                             5627.626544  2278.320561  2342.824444
# 28  1987                             5804.092395  2357.355774  2365.384092
#
#            Gas  Cement.emission    Flaring      Other  Per.Capita
# 24  745.837063       109.932383  58.149786  13.173743    1.103304
# 25  810.618423       112.241889  51.047959  14.256602    1.121407
# 26  841.780200       113.651325  49.620155  15.085236    1.138422
# 27  825.235299       118.541340  46.425142  16.279758    1.134472
# 28  892.716174       123.702117  44.626926  20.307312    1.148751

# %%
df_y2 =(pd.merge(df_ff,df_wilds2))
df_y2.to_csv('./cc/worldfiree.csv')

# %%
df_y2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 37
# Data columns (total 11 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Year                                    38 non-null     int64
#  1   Fires                                   38 non-null     int64
#  2   Acres                                   38 non-null     int64
#  3   fossil.emissions.excluding.carbonation  38 non-null     float64
#  4   Coal                                    38 non-null     float64
#  5   Oil                                     38 non-null     float64
#  6   Gas                                     38 non-null     float64
#  7   Cement.emission                         38 non-null     float64
#  8   Flaring                                 38 non-null     float64
#  9   Other                                   38 non-null     float64
# ...

# %%
pd.plotting.scatter_matrix(df_y,figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Year'>,
#         <AxesSubplot:xlabel='Acres', ylabel='Year'>,
#         <AxesSubplot:xlabel='fossil emissions excluding carbonation', ylabel='Year'>,
#         <AxesSubplot:xlabel='land-use change emissions', ylabel='Year'>,
#         <AxesSubplot:xlabel='atmospheric growth', ylabel='Year'>,
#         <AxesSubplot:xlabel='ocean sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='land sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='cement carbonation sink', ylabel='Year'>,
#         <AxesSubplot:xlabel='budget imbalance', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Acres', ylabel='Fires'>,
#         <AxesSubplot:xlabel='fossil emissions excluding carbonation', ylabel='Fires'>,
#         <AxesSubplot:xlabel='land-use change emissions', ylabel='Fires'>,
# ...

# %%
pd.plotting.scatter_matrix(df_y2,figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Year'>,
#         <AxesSubplot:xlabel='Acres', ylabel='Year'>,
#         <AxesSubplot:xlabel='fossil.emissions.excluding.carbonation', ylabel='Year'>,
#         <AxesSubplot:xlabel='Coal', ylabel='Year'>,
#         <AxesSubplot:xlabel='Oil', ylabel='Year'>,
#         <AxesSubplot:xlabel='Gas', ylabel='Year'>,
#         <AxesSubplot:xlabel='Cement.emission', ylabel='Year'>,
#         <AxesSubplot:xlabel='Flaring', ylabel='Year'>,
#         <AxesSubplot:xlabel='Other', ylabel='Year'>,
#         <AxesSubplot:xlabel='Per.Capita', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Fires', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Acres', ylabel='Fires'>,
#         <AxesSubplot:xlabel='fossil.emissions.excluding.carbonation', ylabel='Fires'>,
#         <AxesSubplot:xlabel='Coal', ylabel='Fires'>,
# ...

# %%
import seaborn as sns

# %%
ig = plt.figure(figsize=(20,20))
sns.heatmap(df_y2.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
ig = plt.figure(figsize=(20,20))
sns.heatmap(df_y.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df_y2, x='Acres', y='fossil.emissions.excluding.carbonation')
plt.title('cal')
# seaborn으로 다음의 차트가 그려보세요.
plt.show()

# %%
sns.scatterplot(data=df_y, x='Acres', y='fossil emissions excluding carbonation')
plt.title('cal')
# seaborn으로 다음의 차트가 그려보세요.
plt.show()

# %%
sns.pairplot(df_y2, hue='Acres')

# %%
sns.pairplot(df_y2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#데이터셔플
from sklearn.metrics import mean_squared_error

# %%
pip list
# Out:
# Package             Version
# ------------------- -------
# argon2-cffi         21.1.0
# attrs               21.2.0
# backcall            0.2.0
# bleach              4.1.0
# cffi                1.15.0
# cycler              0.11.0
# debugpy             1.5.1
# decorator           5.1.0
# defusedxml          0.7.1
# entrypoints         0.3
# importlib-resources 5.4.0
# ipykernel           6.5.0
# ipython             7.29.0
# ipython-genutils    0.2.0
# ipywidgets          7.6.5
# jedi                0.18.0
# Jinja2              3.0.2
# joblib              1.1.0
# jsonschema          4.2.1
# jupyter             1.0.0
# jupyter-client      7.0.6
# jupyter-console     6.4.0
# jupyter-core        4.9.1
# jupyterlab-pygments 0.1.2
# jupyterlab-widgets  1.0.2
# kiwisolver          1.3.2
# MarkupSafe          2.0.1
# matplotlib          3.4.3
# matplotlib-inline   0.1.3
# mistune             0.8.4
# nbclient            0.5.5
# nbconvert           6.2.0
# nbformat            5.1.3
# ...
